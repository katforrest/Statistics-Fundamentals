# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
classifications = pd.read_csv('./met_sample/classification_frequency.csv')
#bestsellers = df[df['Cer'] <= 50]

classifications
# Out:
#              Classification1  Frequency
# 0                  Accessory        294
# 1                  Aerophone       1982
# 2    Aerophone and Idiophone         15
# 3                     Albums       1417
# 4                      Amber         33
# ..                       ...        ...
# 197                      Wax          2
# 198                     Wood       3176
# 199               Woodblocks         71
# 200                 Woodwork       2326
# 201           Works on Paper        255
#
# [202 rows x 2 columns]

# %%
sns.set_theme(palette='husl')
sns.color_palette("husl", 8)
# Out:
# [(0.9677975592919913, 0.44127456009157356, 0.5358103155058701),
#  (0.8087954113106306, 0.5634700050056693, 0.19502642696727285),
#  (0.5920891529639701, 0.6418467016378244, 0.1935069134991043),
#  (0.19783576093349015, 0.6955516966063037, 0.3995301037444499),
#  (0.21044753832183283, 0.6773105080456748, 0.6433941168468681),
#  (0.22335772267769388, 0.6565792317435265, 0.8171355503265633),
#  (0.6423044349219739, 0.5497680051256467, 0.9582651433656727),
#  (0.9603888539940703, 0.3814317878772117, 0.8683117650835491)]

# %%
df = pd.read_csv('./met_sample/classification_frequency.csv')
classifications = df[df['Frequency'] >= 100]

dims = (15, 35)
fig, ax = plt.subplots(figsize=dims)
sns.barplot(ax=ax, data=classifications, x="Frequency", y="Classification")
for i in ax.containers:
    ax.bar_label(i,)

# %%
df = pd.read_csv('./met_sample/class_cent_frequency.csv')
ceramics = df[df['Classification']=='Ceramics']

ceramics
# Out:
#     Classification  CenturyYear  Frequency
# 304       Ceramics         -100         95
# 305       Ceramics        -1000         73
# 306       Ceramics        -1100         18
# 307       Ceramics        -1200         95
# 308       Ceramics        -1300         14
# ..             ...          ...        ...
# 372       Ceramics          501        486
# 373       Ceramics          601        581
# 374       Ceramics          701        728
# 375       Ceramics          801        426
# 376       Ceramics          901        463
#
# [73 rows x 3 columns]

# %%
dims = (25, 10)
fig, ax = plt.subplots(figsize=dims)
sns.barplot(ax=ax, data=ceramics, y="Frequency", x="CenturyYear")
for i in ax.containers:
    ax.bar_label(i,)
    ax.set_title("Ceramics")

# %%
df = pd.read_csv('./met_sample/class_cent_frequency.csv')
textiles = df[df['Classification']=='Textiles']

dims = (15, 10)
fig, ax = plt.subplots(figsize=dims)
sns.barplot(ax=ax, data=textiles, y="Frequency", x="CenturyYear")
for i in ax.containers:
    ax.bar_label(i,)
    ax.set_title("Textiles")

# %%
df = pd.read_csv('./met_sample/class_cent_frequency.csv')
drawings = df[df['Classification']=='Drawings']

dims = (15, 10)
fig, ax = plt.subplots(figsize=dims)
sns.barplot(ax=ax, data=drawings, y="Frequency", x="CenturyYear")
for i in ax.containers:
    ax.bar_label(i,)
    ax.set_title("Drawings")

# %%
df = pd.read_csv('./met_sample/class_cent_frequency.csv')
paintings = df[df['Classification']=='Paintings']

dims = (15, 10)
fig, ax = plt.subplots(figsize=dims)
sns.barplot(ax=ax, data=paintings, y="Frequency", x="CenturyYear")
for i in ax.containers:
    ax.bar_label(i,)
    ax.set_title("Paintings")

# %%
df = pd.read_csv('./met_sample/class_cent_frequency.csv')
glass = df[df['Classification']=='Glass']

dims = (15, 10)
fig, ax = plt.subplots(figsize=dims)
sns.barplot(ax=ax, data=glass, y="Frequency", x="CenturyYear")
for i in ax.containers:
    ax.bar_label(i,)
    ax.set_title("Glass")

# %%
df = pd.read_csv('./met_sample/class_cent_frequency.csv')
paintings_textiles = df[(df['Classification']=='Paintings') | (df['Classification']=='Textiles')]

paintings_textiles
# Out:
#      Classification  CenturyYear  Frequency
# 1411      Paintings            0          9
# 1412      Paintings          100          6
# 1413      Paintings         1001        137
# 1414      Paintings         1101         81
# 1415      Paintings         1201        126
# 1416      Paintings         1301        749
# 1417      Paintings         1401        520
# 1418      Paintings         1501        648
# 1419      Paintings         1601       1145
# 1420      Paintings         1701       1146
# 1421      Paintings         1801       1666
# 1422      Paintings         1901       2750
# 1423      Paintings         2001        123
# 1424      Paintings          201          1
# 1425      Paintings          401         17
# 1426      Paintings          501          2
# 1427      Paintings          601          7
# 1428      Paintings          701          7
# 1429      Paintings          801          5
# 1430      Paintings          901         40
# ...

# %%
dims = (15, 10)
fig, ax = plt.subplots(figsize=dims)
sns.barplot(ax=ax, data=paintings_textiles, y="Frequency", x="CenturyYear", hue="Classification")
for i in ax.containers:
    ax.bar_label(i,)
    ax.set_title("Glass")

# %%
df = pd.read_csv('./met_sample/class_century_frequency.csv')
paintings = df[df['Classification']=='Paintings']
dims = (25, 10)
fig, ax = plt.subplots(figsize=dims)
sns.barplot(ax=ax, data=paintings, y="Frequency", x="Century")
for i in ax.containers:
    ax.bar_label(i,)
    ax.set_title("Paintings")
    plt.xticks(
    rotation=45, 
    horizontalalignment='right',
    fontweight='light',
    fontsize='large')

# %% [markdown]
# Create a spreadsheet that lists all centuries and all classifications, even when frequency = 0
#
# Find a way to modify the X axis labels any way I want, i.e. "400's BCE"
#
# Then compare the two data sets, like glass vs paintings.
#
# Is there data cleaning to do? Like looking for outliers?
#
# What about the subclasses?
#
# Download more data - does MET have dull dataset for download?
